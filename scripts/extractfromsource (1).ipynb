# %%
#Download Libraries
# !pip install azure-storage-blob

# %%
#Import Libraries
import pandas as pd
import numpy as np
import json
import requests
import csv
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %%
#Extracting from datasource
#Extracting from datasource
df_raw = pd.read_csv("DOB_Permit_Issuance_20240407.csv")

print(df_raw.info)
print(df_raw.shape)
df_raw.head()
# Out:
# <ipython-input-20-4afb2eded34b>:3: DtypeWarning: Columns (9,10,31,33,36,47,48,49,50,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv("DOB_Permit_Issuance_20240407.csv")
# <bound method DataFrame.info of               BOROUGH    Bin # House #       Street Name      Job #  \
# 0           MANHATTAN  1088749       1       MADISON AVE  141008987
# 1       STATEN ISLAND  5076937      87     BOYLAN STREET  540218539
# 2       STATEN ISLAND  5001506     217  LAFAYETTE AVENUE  540218575
# 3       STATEN ISLAND  5067021     170    OAKDALE STREET  540218600
# 4       STATEN ISLAND  5058036     273         10 STREET  540218628
# ...               ...      ...     ...               ...        ...
# 321711       BROOKLYN  3000468       4   FLATBUSH AVENUE  300982284
# 321712      MANHATTAN  1046853    1050       PARK AVENUE  102865794
# 321713      MANHATTAN  1050751     407  EAST   91 STREET  103330646
# ...

# %%
#Specify the path to your JSON configuration file
config_file_path= 'config.json'

#Load the JSON configuration file
with open (config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'dobpermitissuance'
blob_name = "dobpermitissuance202407.csv"

#Convert Dataframe to CSV
output = StringIO()
df_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

#Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

#Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Upload {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}")
# Out:
# Upload dobpermitissuance202407.csv to Azure Blob Storage in container dobpermitissuance
